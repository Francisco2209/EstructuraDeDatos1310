# %% [markdown]
# <a href="https://colab.research.google.com/github/Francisco2209/EstructuraDeDatos1310/blob/main/Tarea_11_EDD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class BinaryNode:
    def __init__( self , value , left=None , right= None ):
        self.data = value
        self.left = left
        self.right = right

class BinarySearchTree:
    def __init__( self ):
        self.root = None
    
    def insert( self , value ):
        if self.root == None:
            self.root = BinaryNode( value )
        else:
            self.__insert_nodo( self.root , value )
        
    def __insert_nodo(self , nodo , value ):
        if nodo.data == value: 
            pass
        elif value < nodo.data:# ir a la izq
            if nodo.left == None:
                nodo.left = BinaryNode( value )
            else:
                self.__insert_nodo( nodo.left , value )
        else:  # ir a la derecha
            if nodo.right == None:
                nodo.right = BinaryNode( value )
            else:
                self.__insert_nodo( nodo.right , value )
    
    def transversal( self , formato = "posorden"):
        if formato == "posorden":
            self.recorrido_pos( self.root )
        elif formato == "preorden":
            self.recorrido_pre(self.root )
        else: # inorden
            self.recorrido_in( self.root )
        print()

    def  recorrido_pos( self , nodo ):
        if nodo != None:
            self.recorrido_pos( nodo.left )
            self.recorrido_pos( nodo.right )
            print( str(nodo.data) , end=" , " )
    
    def  recorrido_pre( self , nodo ):
        if nodo != None:
            print( str(nodo.data) , end=" , " )
            self.recorrido_pre( nodo.left )
            self.recorrido_pre( nodo.right )
    
    def  recorrido_in( self , nodo ):
        if nodo != None:
            self.recorrido_in( nodo.left )
            print( str(nodo.data) , end=" , " )
            self.recorrido_in( nodo.right ) 

    def search( self , value ):
        if self.root == None:
            print("El arbol está vacío")
            return None
        else:
            return self.__search( self.root , value )

    def __search( self , nodo , value ):
        if nodo == None:
            print("El dato no existe en el arbol") 
            return None
        elif nodo.data == value:
            print("Encontrado", nodo.data)
            return nodo
        elif value < nodo.data:
            return self.__search( nodo.left , value  )
        else:
            return self.__search( nodo.right , value  ) 

    def remove( self , value ):
        if self.root == None:
            print("El arbol está vacio")
            return None
        else:
            return self.__remove( self.root , value )

    def __remove( self , nodo , value ):
        if self.root == None:
            print( "El dato no se encuentra en el arbol" )
            return None

        elif nodo.data == value:
            if nodo.left == None and nodo.right == None:
                nodo.data = None
            elif nodo.left != None and nodo.right == None:
                nodo.data = nodo.left.data
                nodo.left = self.insert( nodo.left.data )
            elif nodo.right != None and nodo.left == None:
                nodo.data = nodo.right.data
                nodo.right = None
            elif nodo.left != None and nodo.right != None:
                nodo.data = nodo.right.data
                nodo.right = None
                

        elif value < nodo.data:
            return self.__remove( nodo.left , value  )

        else:
            return self.__remove( nodo.right , value  )

# %%
abb = BinarySearchTree()
abb.insert(30)
abb.insert(15)
abb.insert(45)
abb.insert(12)
abb.insert(17)
abb.insert(50)
abb.insert(55)
abb2 = BinarySearchTree()
abb2.insert(30)
abb2.insert(15)
abb2.insert(45)
abb2.insert(12)
abb2.insert(17)
abb2.insert(50)
abb2.insert(55)
abb3 = BinarySearchTree()
abb3.insert(30)
abb3.insert(15)
abb3.insert(45)
abb3.insert(12)
abb3.insert(17)
abb3.insert(50)
abb3.insert(55)
abb3.transversal("posorden")
print("\n")
print("------------Eliminando nodo hoja (55)-----------")
abb.remove(55)
abb.transversal("posorden")
print("\n")
print("------------Eliminando nodo con un hijo (50)------------")
abb2.remove(50)
abb2.transversal("posorden")
print("\n")
print("------------Eliminando nodo con dos hijos (15)------------")
abb3.remove(15)
abb3.transversal("posorden")
# Out:
# 12 , 17 , 15 , 55 , 50 , 45 , 30 ,
#
#
# ------------Eliminando nodo hoja (55)-----------
# 12 , 17 , 15 , None , 50 , 45 , 30 ,
#
#
# ------------Eliminando nodo con un hijo (50)------------
# 12 , 17 , 15 , 55 , 45 , 30 ,
#
#
# ------------Eliminando nodo con dos hijos (15)------------
# 12 , 17 , 55 , 50 , 45 , 30 ,
