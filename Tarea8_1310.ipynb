# %% [markdown]
# <a href="https://colab.research.google.com/github/Francisco2209/EstructuraDeDatos1310/blob/main/Tarea8_1310.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class NodoDoble:
    def __init__( self , value , siguiente = None , previo = None ):
        self.data = value
        self.next = siguiente
        self.prev = previo

# %%
#Ejercicio 1
head = NodoDoble(10)
tail = head

print( head.data )
print( tail.data )

#Ejerccio 2
print( "Ejercicio 2" )
head = NodoDoble( 10 , NodoDoble(20) )
head.next.prev = head 
tail = head.next 

print( "El primero:" , head.data)
print( "El primero:" , tail.prev.data)

print( "El segundo:" , head.next.data)
print( "El segundo:" , tail.data)

"""
Lo mismo pero con 4 nodos 10,20,30,40
imprimir el valordel primero
imprimir el valor del ultimo
"""

#Ejercicio 3
print( "Ejercicio 3" )
head = NodoDoble( 10 , NodoDoble( 20 , NodoDoble( 30 , NodoDoble(40))))
tail = head.next.next.next
head.next.prev = head
head.next.next.prev = head.next
tail.prev = head.next.next

print( "El primero:" , head.data)
print( "El primero:" , tail.prev.prev.prev.data)

print( "El ultimo:" , head.next.next.next.data)
print( "El ultimo:" , tail.data)

print( "El transversal:" , head.data)
print( "El transversal:" , tail.prev.prev.prev.data)

#Transversal
curr_node = head
while curr_node != None:
  print(f"|{curr_node.data}|-->", end="")
  curr_node = curr_node.next
print("")

#reverse transversal
curr_node = tail
while curr_node != None:
    print( f"|{curr_node.data}|-->", end="")
    curr_node = curr_node.prev
print("")

#agregar nodo al final
print("agregar el 50 al final")
tail.next = NodoDoble( 50 , None , tail )
tail = tail.next

#Transversal
curr_node = head
while curr_node != None:
  print(f"|{curr_node.data}|-->", end="")
  curr_node = curr_node.next
print("")

#reverse transversal
curr_node = tail
while curr_node != None:
    print( f"|{curr_node.data}|-->", end="")
    curr_node = curr_node.prev
print("")

# %%
class DoubleLinkedList:
    def __init__( self ):
        self.head = None
        self.tail = None
        self.size = 0

    def get_size( self ):
        return self.size

    def is_empty( self ): #true si la lista está vacia
        return self.size == 0

    def append( self , value ):
        if self.is_empty():
            self.head = NodoDoble( value )
            self.tail = self.head
        else:
            self.tail.next = NodoDoble( value, None , self.tail )
            self.tail = self.tail.next
        self.size += 1

    def transversal( self ):
        curr_node = self.head 
        while curr_node != None:
            print(f"| {curr_node.data} | --> " , end="")
            curr_node = curr_node.next
        print("")

    def reverse_transversal( self ):
        curr_node = self.tail 
        while curr_node != None:
            print( f"| {curr_node.data} | --> " , end="" )
            curr_node = curr_node.prev
        print("")

    def find_from_head( self , value ):
        curr_node = self.head
        while curr_node.data != value:
            
            print( f"| {curr_node.data} | --> " , end="" )
            curr_node = curr_node.next
        print(f"| {value} |")

    def find_from_tail( self , value ):
        curr_node = self.tail
        while curr_node.data != value:
            
            print( f"| {curr_node.data} | --> " , end="" )
            curr_node = curr_node.prev
        print(f"| {value} |")
            
    def remove_from_head( self , value ):
        curr_node = self.head
        while curr_node.data != value:
            curr_node = curr_node.next

        if curr_node.data == value:
            curr_node.prev.next = curr_node.next 
            curr_node.next.prev = curr_node.prev
        self.size -= 1

    def remove_from_tail( self , value ):
        curr_node = self.tail 
        while curr_node.data != value:
            curr_node = curr_node.prev

        if curr_node.data == value:
            curr_node.next.prev = curr_node.prev
            curr_node.prev.next = curr_node.next
        self.size -= 1

# %%
ldl = DoubleLinkedList()
ldl.append(10)
ldl.append(20)
ldl.append(30)
ldl.append(40)
print( "Tranversal:" )
ldl.transversal()
print( "Reverse Tranversal:" )
ldl.reverse_transversal()
print(f"Size: { ldl.get_size() }")
print( f"Is empty? { ldl.is_empty() }" )
ldl2 = DoubleLinkedList()
ldl2.append(10)
ldl2.append(20)
ldl2.append(30)
ldl2.append(40)
ldl2.append(50)
print( "Find(30) from Head :" )
ldl2.find_from_head(30)
print( "Find(20) from Tail :" )
ldl2.find_from_tail(20)
print( "Remove(30) from Head :" )
ldl.remove_from_head(30)
ldl.transversal()
print( "Remove(20) from Tail :" )
ldl2.remove_from_tail(20)
ldl2.transversal()
# Out:
# Tranversal:
# | 10 | --> | 20 | --> | 30 | --> | 40 | -->
# Reverse Tranversal:
# | 40 | --> | 30 | --> | 20 | --> | 10 | -->
# Size: 4
# Is empty? False
# Find(30) from Head :
# | 10 | --> | 20 | --> | 30 |
# Find(20) from Tail :
# | 50 | --> | 40 | --> | 30 | --> | 20 |
# Remove(30) from Head :
# | 10 | --> | 20 | --> | 40 | -->
# Remove(20) from Tail :
# | 10 | --> | 30 | --> | 40 | --> | 50 | -->
